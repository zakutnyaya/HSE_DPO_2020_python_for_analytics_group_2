# %% [markdown]
# # Python для анализа данных
#
# *Алла Тамбовцева, Валентин Бирюков НИУ ВШЭ*
#
# ## Домашнее задание №8

# %% [markdown]
# ### Часть 1: файл csv

# %% [markdown]
# **1.** Загрузите csv-файл с таблицей по ссылке. Описание данных см. [здесь](https://vincentarelbundock.github.io/Rdatasets/doc/Ecdat/Fishing.html).

# %%
import pandas as pd
df = pd.read_csv('Fishing.csv', index_col = 0)
df.head()
# Out:
#       mode    price   catch   pbeach    ppier    pboat  pcharter  cbeach  \
# 1  charter  182.930  0.5391  157.930  157.930  157.930   182.930  0.0678
# 2  charter   34.534  0.4671   15.114   15.114   10.534    34.534  0.1049
# 3     boat   24.334  0.2413  161.874  161.874   24.334    59.334  0.5333
# 4     pier   15.134  0.0789   15.134   15.134   55.930    84.930  0.0678
# 5     boat   41.514  0.1082  106.930  106.930   41.514    71.014  0.0678
#
#     cpier   cboat  ccharter     income
# 1  0.0503  0.2601    0.5391  7083.3317
# 2  0.0451  0.1574    0.4671  1249.9998
# 3  0.4522  0.2413    1.0266  3749.9999
# 4  0.0789  0.1643    0.5391  2083.3332
# 5  0.0503  0.1082    0.3240  4583.3320

# %% [markdown]
# **2.** Выведите описательные статистики для всех числовых (integer, float) переменных в датафрейме.

# %%
df.loc[:,'price':].describe()
# Out:
#              price        catch       pbeach        ppier        pboat  \
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean     52.081975     0.389368   103.422005   103.422005    55.256570
# std      53.829970     0.560596   103.641042   103.641042    62.713444
# min       1.290000     0.000200     1.290000     1.290000     2.290000
# 25%      15.870000     0.036100    26.656500    26.656500    13.122000
# 50%      37.896000     0.164300    74.628000    74.628000    33.534000
# 75%      67.513000     0.533300   144.144000   144.144000    72.402000
# max     666.110000     2.310100   843.186000   843.186000   666.110000
#
#           pcharter       cbeach        cpier        cboat     ccharter  \
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean     84.379244     0.241011     0.162224     0.171215     0.629368
# std      63.544650     0.190752     0.160390     0.209789     0.706114
# min      27.290000     0.067800     0.001400     0.000200     0.002100
# 25%      42.896000     0.067800     0.050300     0.023300     0.021900
# 50%      61.607000     0.253700     0.078900     0.089700     0.421600
# 75%     102.774000     0.533300     0.149800     0.241300     1.026600
# max     691.110000     0.533300     0.452200     0.736900     2.310100
#
#              income
# count   1182.000000
# mean    4099.337054
# std     2461.964060
# min      416.666680
# 25%     2083.333200
# 50%     3749.999900
# 75%     5416.666700
# max    12499.998000

# %% [markdown]
# **3.** Выберите из таблицы только строки, которые соответствуют респондентам, которые выбрали рыбалку на берегу (`beach`).

# %%
df[df['mode'] == 'beach']
# Out:
#        mode    price   catch   pbeach    ppier    pboat  pcharter  cbeach  \
# 7     beach   51.934  0.0678   51.934   51.934  191.930   220.930  0.0678
# 15    beach   74.514  0.2537   74.514   74.514   74.514    93.014  0.2537
# 17    beach   48.114  0.1049   48.114   48.114   33.534    57.534  0.1049
# 26    beach   67.784  0.5333   67.784   67.784   17.862    52.862  0.5333
# 34    beach    9.522  0.0678    9.522    9.522   78.292   107.292  0.0678
# 1031  0.4522  0.2413    1.0266   2916.66660
# 1036  0.4522  0.2413    1.0266   1249.99980
# 1043  0.4522  0.1665    0.3975   3749.99990
# 1055  0.4522  0.0156    0.0058   3749.99990
# 1074  0.4522  0.0156    0.0058   2916.66660
# 1094  0.4522  0.2413    1.0266   5416.66670
# 1105  0.1498  0.0008    0.0027   6250.00130
# 1115  0.4522  0.2413    1.0266   4583.33200
# 1120  0.4522  0.2413    1.0266   2916.66660
# 1121  0.4522  0.2413    1.0266   2916.66660
# 1123  0.4522  0.1665    0.3975   4583.33200
# 1124  0.4522  0.2413    1.0266   7083.33170
# 1154  0.1498  0.0233    0.0219   7083.33170
# 1160  0.1498  0.2339    0.6288   2916.66660
# 1168  0.4522  0.0156    0.0058   2083.33320
# 1174  0.0789  0.0014    0.0029   2916.66660
# 1177  0.4522  0.2413    1.0266   2916.66660
# 1179  0.4522  0.2413    1.0266   6250.00130
# 1181  0.4522  0.1665    0.3975    416.66668
#
# [134 rows x 12 columns]

# %% [markdown]
# **4.** Выберите из таблицы строки, которые соответствуют респондентам, которые предпочитают рыбачить на лодке (`boat`) с доходом (`income`) ниже 3500. Сохраните результат в переменную `boat_data`.

# %%
boat_data = df[(df['mode'] == 'boat') & (df['income'] < 3500)]

# %% [markdown]
# **5.** Переименуйте столбец `catch` в `c_rate`.

# %%
my_cols = list(df.columns)
my_cols[2] = 'c_rate'
df.columns = my_cols
# Out:
#       mode    price  c_rate   pbeach    ppier    pboat  pcharter  cbeach  \
# 1  charter  182.930  0.5391  157.930  157.930  157.930   182.930  0.0678
# 2  charter   34.534  0.4671   15.114   15.114   10.534    34.534  0.1049
# 3     boat   24.334  0.2413  161.874  161.874   24.334    59.334  0.5333
# 4     pier   15.134  0.0789   15.134   15.134   55.930    84.930  0.0678
# 5     boat   41.514  0.1082  106.930  106.930   41.514    71.014  0.0678
#
#     cpier   cboat  ccharter     income
# 1  0.0503  0.2601    0.5391  7083.3317
# 2  0.0451  0.1574    0.4671  1249.9998
# 3  0.4522  0.2413    1.0266  3749.9999
# 4  0.0789  0.1643    0.5391  2083.3332
# 5  0.0503  0.1082    0.3240  4583.3320

# %% [markdown]
# **6.** Добавьте в таблицу столбец `log_income`, содержащий натуральный логарифм доходов респондентов.

# %%
from math import log
df['log_income'] = df.income.apply(log)

# %% [markdown]
# **7.** Сгруппируйте наблюдения в таблице по признаку тип рыбалки (`mode`) и выведите для каждого типа среднюю цену (`price`), которую респонденты готовы заплатить за рыбалку.

# %%
pd.DataFrame(df.groupby('mode').price.mean())
# Out:
#              price
# mode
# beach    35.699493
# boat     41.606813
# charter  75.096942
# pier     30.571326

# %% [markdown]
# **8.** Постройте гистограмму для показателя `pboat`, поменяйте ее цвет и добавьте название графика.

# %%
import matplotlib as plt
# %matplotlib inline

plot = df.pboat.hist(color='turquoise')
plot.set_title('Distribution of price for private boat mode')
plot.set_xlabel('Price')
plot.set_ylabel('Frequency')

# %% [markdown]
# **9.** Выведите на экран первые 8 строк таблицы. А теперь последние 8.

# %%
df.head(8)
# Out:
#       mode    price  c_rate   pbeach    ppier    pboat  pcharter  cbeach  \
# 1  charter  182.930  0.5391  157.930  157.930  157.930   182.930  0.0678
# 2  charter   34.534  0.4671   15.114   15.114   10.534    34.534  0.1049
# 3     boat   24.334  0.2413  161.874  161.874   24.334    59.334  0.5333
# 4     pier   15.134  0.0789   15.134   15.134   55.930    84.930  0.0678
# 5     boat   41.514  0.1082  106.930  106.930   41.514    71.014  0.0678
# 6  charter   63.934  0.3975  192.474  192.474   28.934    63.934  0.5333
# 7    beach   51.934  0.0678   51.934   51.934  191.930   220.930  0.0678
# 8  charter   56.714  0.0209   15.134   15.134   21.714    56.714  0.0678
#
#     cpier   cboat  ccharter     income  log_income
# 1  0.0503  0.2601    0.5391  7083.3317    8.865500
# 2  0.0451  0.1574    0.4671  1249.9998    7.130899
# 3  0.4522  0.2413    1.0266  3749.9999    8.229511
# 4  0.0789  0.1643    0.5391  2083.3332    7.641724
# 5  0.0503  0.1082    0.3240  4583.3320    8.430182
# 6  0.4522  0.1665    0.3975  4583.3320    8.430182
# 7  0.0789  0.1643    0.5391  8750.0010    9.076809
# 8  0.0789  0.0102    0.0209  2083.3332    7.641724

# %%
df.tail(8)
# Out:
#          mode    price  c_rate   pbeach    ppier    pboat  pcharter  cbeach  \
# 1175     boat   86.802  0.0102   91.834   91.834   86.802   121.802  0.0678
# 1176  charter  149.402  0.0209  121.034  121.034  114.402   149.402  0.0678
# 1177    beach  121.836  0.5333  121.836  121.836  203.346   238.346  0.5333
# 1178     pier  150.236  0.4522  150.236  150.236  250.746   285.746  0.5333
# 1179    beach  235.436  0.5333  235.436  235.436  392.946   427.946  0.5333
# 1180     pier   65.036  0.4522   65.036   65.036  108.546   143.546  0.5333
# 1181    beach   36.636  0.5333   36.636   36.636   61.146    96.146  0.5333
# 1182     boat  235.436  0.6817  339.890  339.890  235.436   260.436  0.2537
#
#        cpier   cboat  ccharter      income  log_income
# 1175  0.0789  0.0102    0.0209  4583.33200    8.430182
# 1176  0.0789  0.0102    0.0209  6250.00130    8.740337
# 1177  0.4522  0.2413    1.0266  2916.66660    7.978197
# 1178  0.4522  0.2413    1.0266  3749.99990    8.229511
# 1179  0.4522  0.2413    1.0266  6250.00130    8.740337
# 1180  0.4522  0.2413    1.0266  1249.99980    7.130899
# 1181  0.4522  0.1665    0.3975   416.66668    6.032287
# 1182  0.1498  0.6817    2.3014  6250.00130    8.740337

# %% [markdown]
# **10.** Сохраните изменённый датафрейм в csv-файл.

# %%
df.to_csv('Fishing_modified')

# %% [markdown]
# ### Часть 2: файл Excel
#
# **Файл для работы**
#
# polit.xlsx
#
# **Описание файла**
#
# сокращенная версия файла `PetersMcGuireData.xlsx`, взятого [отсюда](http://jmcguire.faculty.wesleyan.edu/welcome/data/#20LActries) (страница James W.McGuire, Data used in “Authoritarianism in the Middle East”).
#
# **Переменные:**
#
# * `ctry` – country;
# * `fh09` – Freedom House index (ranging from 1 (most) to 7 (fewest) political rights and civil liberties), 2009;
# * `polity09` – Polity2 score (ranging from -10 to +10, latter most democratic), 2009;
# * `gini` – Gini index of income inequality, 2000-2010;
# * `fparl08` – female share of seats in parliament (%), 2008;
# * `mena` – Middle East and North Africa (1 - yes, 0 - no);
# * `lati` – Latin America (1 - yes, 0 - no);
# * `cari` – Caribbean, former British, French, Dutch colony;
# * `east` – East Asia;
# * `sovi` – Former Soviet Bloc;
# * `afri` – Africa;
# * `corr0509` – Control of Corruption, average 2005-2009 (expert rating).

# %%
polit = pd.read_excel('https://github.com/rogovich/2019_HSE_DPO_Python_for_data_analysis/blob/master/homeworks/10-23-2019_HW_Pandas/polit.xlsx?raw=true')
polit.head()
# Out:
#              ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  \
# 0     Afghanistan   6.0       0.0   NaN    25.87     0     0     0     0
# 1         Albania   3.0       9.0  33.0     7.14     0     0     0     0
# 2         Algeria   5.5       2.0  35.3     6.48     1     0     0     0
# 3  American Samoa   NaN       NaN   NaN      NaN     0     0     0     0
# 4         Andorra   1.0       NaN   NaN    25.00     0     0     0     0
#
#    sovi  afri  corr0509
# 0     0     0 -1.550910
# 1     1     0 -0.580513
# 2     0     0 -0.434654
# 3     0     0  0.442991
# 4     0     0  1.307767

# %% [markdown]
# **1.** Загрузите таблицу из файла `polit.xlsx` и сохраните ее в переменную `df`.

# %%
df = pd.read_excel('polit.xlsx')
df.head()
# Out:
#              ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  \
# 0     Afghanistan   6.0       0.0   NaN    25.87     0     0     0     0
# 1         Albania   3.0       9.0  33.0     7.14     0     0     0     0
# 2         Algeria   5.5       2.0  35.3     6.48     1     0     0     0
# 3  American Samoa   NaN       NaN   NaN      NaN     0     0     0     0
# 4         Andorra   1.0       NaN   NaN    25.00     0     0     0     0
#
#    sovi  afri  corr0509
# 0     0     0 -1.550910
# 1     1     0 -0.580513
# 2     0     0 -0.434654
# 3     0     0  0.442991
# 4     0     0  1.307767

# %% [markdown]
# **2.** Выведите общую информацию по таблице: число строк и столбцов, типы данных в таблице. Есть ли в таблице пропущенные значения?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 12 columns):
# ctry        213 non-null object
# fh09        191 non-null float64
# polity09    159 non-null float64
# gini        146 non-null float64
# fparl08     186 non-null float64
# mena        213 non-null int64
# lati        213 non-null int64
# cari        213 non-null int64
# east        213 non-null int64
# sovi        213 non-null int64
# afri        213 non-null int64
# corr0509    203 non-null float64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 20.0+ KB

# %% [markdown]
# **3.** Если в таблице есть строки с пропущенными значениями, удалите их. Сохраните изменения в `df`.

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135 entries, 1 to 212
# Data columns (total 12 columns):
# ctry        135 non-null object
# fh09        135 non-null float64
# polity09    135 non-null float64
# gini        135 non-null float64
# fparl08     135 non-null float64
# mena        135 non-null int64
# lati        135 non-null int64
# cari        135 non-null int64
# east        135 non-null int64
# sovi        135 non-null int64
# afri        135 non-null int64
# corr0509    135 non-null float64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 13.7+ KB

# %% [markdown]
# **4.** Выведите на экран описательные статистики по всем количественным переменным в таблице. Выберите какой-нибудь интересующий вас столбец и проинтерпретируйте описательные статистики по нему (т.е. опишите «обычными» словами, что значат значения типа `min`, `std`, `50%` и так далее).

# %%
quant_cols = ['fh09', 'polity09', 'gini', 'fparl08','corr0509']
df[quant_cols].describe()
# Out:
#              fh09    polity09        gini     fparl08    corr0509
# count  135.000000  135.000000  135.000000  135.000000  135.000000
# mean     3.325926    4.651852   40.569630   18.348074   -0.104802
# std      1.796886    5.636129    9.432987   10.410612    0.993943
# min      1.000000  -10.000000   16.800000    0.000000   -1.462697
# 25%      1.500000    0.000000   34.000000   10.340000   -0.789189
# 50%      3.500000    7.000000   39.200000   16.110000   -0.406013
# 75%      5.000000    9.000000   47.100000   25.335000    0.342066
# max      7.000000   10.000000   74.300000   50.940000    2.378324

# %% [markdown]
# ### Описание для столбца fparl08
#
# **mean**: основываясь на текущей выборке, в среднем женщины занимают 18.3% мест в парламенте;
#
# **std**: в среднем от наблюдения к наблюдению показатель "процент женщин в парламенте" отклоняется от среднего значения на 10.4%.
#
# **min**: самое низкое количество мест в парламенте, выделенных женщинам, - это 0 мест;
#
# **25%**: в 25% стран из выборки женщинам выделены 10.4% мест в парламенте или меньше;
#
# **50%**: в 50% стран из выборки женщинам выделены 16.1% мест в парламенте или меньше, это медиана выборки;
#
# **75%**: в 75% стран из выборки женщинам выделены 25.3% мест в парламенте или меньше;
#
# **max**: самый выскоий процент женщин в парламенте в рамках выборки - это 50.9%.

# %% [markdown]
# **5.** Выберите в таблице строки, которые соответствуют странам со значениями Freedom House (`fh09`) выше 5. Сохраните их в переменную `not_free`.

# %%
not_free = df[df['fh09'] > 5]

# %% [markdown]
# **6.** Выберите в таблице строки, которые соответствуют странам Африки (`afri`) с процентом женщин в парламенте выше 30%.

# %%
df[(df['afri'] == 1) & (df['fparl08'] > 30)]
# Out:
#              ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  \
# 30        Burundi   4.5       6.0  33.3    31.74     0     0     0     0
# 133    Mozambique   3.5       5.0  47.1    34.80     0     0     0     0
# 160        Rwanda   5.5      -3.0  46.7    50.94     0     0     0     0
# 174  South Africa   2.0       9.0  57.8    33.92     0     0     0     0
# 187      Tanzania   3.5      -1.0  34.6    30.41     0     0     0     0
# 198        Uganda   4.5      -1.0  42.6    30.72     0     0     0     0
#
#      sovi  afri  corr0509
# 30      0     1 -1.095802
# 133     0     1 -0.524405
# 160     0     1 -0.164223
# 174     0     1  0.332960
# 187     0     1 -0.439213
# 198     0     1 -0.819751

# %% [markdown]
# **7.** Выберите в таблице строки, которые соответствуют странам Африки или Латинской Америки (`afri` и `lati`) со значением `polity09` больше или равным 8.

# %%
df[((df['afri'] == 1) | (df['lati'] == 1)) & (df['polity09'] >= 8)]
# Out:
#                    ctry  fh09  polity09  gini  fparl08  mena  lati  cari  \
# 7             Argentina   2.0       8.0  48.8    39.76     0     1     0
# 25             Botswana   2.5       8.0  61.0    11.11     0     0     0
# 26               Brazil   2.0       8.0  55.0     9.43     0     1     0
# 39                Chile   1.0      10.0  52.0    12.66     0     1     0
# 42              Comoros   3.5       9.0  64.3     3.03     0     0     0
# 45           Costa Rica   1.0      10.0  48.9    36.84     0     1     0
# 54   Dominican Republic   2.0       8.0  48.4    17.14     0     1     0
# 57          El Salvador   2.5       8.0  46.9    16.67     0     1     0
# 71                Ghana   1.5       8.0  42.8     7.89     0     0     0
# 77            Guatemala   4.0       8.0  53.7    12.03     0     1     0
# 108             Lesotho   3.0       8.0  52.5    25.83     0     0     0
# 126              Mexico   2.5       8.0  51.6    22.13     0     1     0
# 141           Nicaragua   4.0       9.0  52.3    18.48     0     1     0
# 149              Panama   1.5       9.0  54.9    16.67     0     1     0
# 151            Paraguay   3.0       8.0  53.2    13.60     0     1     0
# 152                Peru   2.5       9.0  50.5    29.17     0     1     0
# 174        South Africa   2.0       9.0  57.8    33.92     0     0     0
# 203             Uruguay   1.0      10.0  47.1    12.31     0     1     0
#
#      east  sovi  afri  corr0509
# 7       0     0     0 -0.420793
# 25      0     0     1  0.947725
# 26      0     0     0 -0.119536
# 39      0     0     0  1.370524
# 42      0     0     1 -0.709136
# 45      0     0     0  0.483973
# 54      0     0     0 -0.618924
# 57      0     0     0 -0.288100
# 71      0     0     1 -0.031224
# 77      0     0     0 -0.681574
# 108     0     0     1 -0.028651
# 126     0     0     0 -0.245729
# 141     0     0     0 -0.747011
# 149     0     0     0 -0.311231
# 151     0     0     0 -1.190401
# 152     0     0     0 -0.310562
# 174     0     0     1  0.332960
# 203     0     0     0  1.112514

# %% [markdown]
# **8.** Отсортируйте строки в таблице в соответствии со значениями столбца со средними значениями индекса Control of Corruption (`corr0509`) по убыванию и выведите: первые 10 строк; последние 10 строк. Используйте метод `.sort_values()`.
#
# *Пример:*
#
#     df.sort_values('column_name', ascending = False) # ascend - возрастать

# %%
df.sort_values('corr0509', ascending = False).head(10)
# Out:
#             ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  sovi  \
# 51       Denmark   1.0      10.0  24.7    37.99     0     0     0     0     0
# 64       Finland   1.0      10.0  26.9    41.50     0     0     0     0     0
# 140  New Zealand   1.0      10.0  36.2    33.61     0     0     0     0     0
# 169    Singapore   4.5      -2.0  42.5    24.47     0     0     0     1     0
# 183       Sweden   1.0      10.0  25.0    46.99     0     0     0     0     0
# 137  Netherlands   1.0      10.0  30.9    39.11     0     0     0     0     0
# 184  Switzerland   1.0      10.0  33.7    27.24     0     0     0     0     0
# 10     Australia   1.0      10.0  35.2    29.65     0     0     0     0     0
# 145       Norway   1.0      10.0  25.8    36.09     0     0     0     0     0
# 33        Canada   1.0      10.0  32.6    24.94     0     0     0     0     0
#
#      afri  corr0509
# 51      0  2.378324
# 64      0  2.335072
# 140     0  2.278719
# 169     0  2.198528
# 183     0  2.147108
# 137     0  2.061414
# 184     0  2.058661
# 10      0  1.979293
# 145     0  1.946725
# 33      0  1.942539

# %%
df.sort_values('corr0509', ascending = False).tail(10)
# Out:
#                  ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  \
# 46      Cote d'Ivoire   5.5       0.0  48.4     8.87     0     0     0     0
# 105           Lao PDR   6.5      -7.0  32.6    25.22     0     0     0     1
# 15         Bangladesh   3.5       5.0  31.0     6.33     0     0     0     0
# 5              Angola   5.5      -2.0  58.6    37.27     0     0     0     0
# 150  Papua New Guinea   3.5       4.0  50.9     0.92     0     0     0     0
# 81              Haiti   4.5       5.0  59.5     5.17     0     1     0     0
# 37               Chad   6.5      -2.0  39.8     5.16     0     0     0     0
# 212          Zimbabwe   6.0       1.0  50.1    18.15     0     0     0     0
# 43   Congo, Dem. Rep.   6.0       5.0  44.4     7.73     0     0     0     0
# 89               Iraq   5.5       0.0  38.3    25.45     1     0     0     0
#
#      sovi  afri  corr0509
# 46      0     1 -1.198933
# 105     0     0 -1.206055
# 15      0     0 -1.218595
# 5       0     0 -1.292684
# 150     0     0 -1.324521
# 81      0     0 -1.336122
# 37      0     1 -1.346880
# 212     0     1 -1.382121
# 43      0     1 -1.428074
# 89      0     0 -1.462697

# %% [markdown]
# **9.** Добавьте в `df` столбец corr_round, в котором будут храниться округленные до 2 знака после запятой значения индекса Control of Corruption (`corr0509`).

# %%
df['corr_round'] = df['corr0509'].apply(lambda x: round(x, 2))

# %%
df.head()
# Out:
#         ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  sovi  \
# 1    Albania   3.0       9.0  33.0     7.14     0     0     0     0     1
# 2    Algeria   5.5       2.0  35.3     6.48     1     0     0     0     0
# 5     Angola   5.5      -2.0  58.6    37.27     0     0     0     0     0
# 7  Argentina   2.0       8.0  48.8    39.76     0     1     0     0     0
# 8    Armenia   5.0       5.0  30.2     8.40     0     0     0     0     0
#
#    afri  corr0509  corr_round
# 1     0 -0.580513       -0.58
# 2     0 -0.434654       -0.43
# 5     0 -1.292684       -1.29
# 7     0 -0.420793       -0.42
# 8     0 -0.578211       -0.58

# %% [markdown]
# **10.** Добавьте в `df` столбец `fh_status`, в котором будут храниться типы стран в зависимости от значения индекса Freedom House (значения free, partly free, not free). Соответствие значений `fh09` с типами стран см. [здесь](https://freedomhouse.org/report/freedom-world-2016/methodology) (в конце, Table 3).

# %%
fh_status = []
for value in df['fh09']:
    if value >= 1 and value <= 2.5:
        fh_status.append('free')
    elif value >= 3 and value <= 5:
        fh_status.append('partly free')
    elif value >= 5.5 and value <= 7:
        fh_status.append('not free')
        
df['fh_status'] = fh_status

# %% [markdown]
# **11.** Сгруппируйте строки в таблице в соответствии со значениями столбца `fh_status`, полученного в предыдущей части и выведите минимальное, среднее и максимальное значение показателя `gini` (индекс Джини) по каждой группе.

# %%
df.groupby('fh_status')['gini'].agg(['min', 'mean', 'max'])
# Out:
#               min       mean   max
# fh_status
# free         24.7  38.170175  74.3
# not free     16.8  39.750000  58.6
# partly free  29.8  43.931250  64.3

# %% [markdown]
# **12.** Сгруппируйте строки в таблице в соответствии со значениями столбца `fh_status` и запишите строки, относящиеся к разным группам, в отдельные csv-файлы.
#
# *Подсказка:* используйте цикл for и перебирайте в нем пары название группы-датафрейм. Попробуйте прогнать следующий код и посмотреть, что получится:
#
#     for name, table in df.groupby('fh_status'):
#         print(name, table.head(2))
#
# Сочетая функционал `pandas` и `matplotlib`, постройте диаграмму рассеяния (scatterplot, функция `scatter()`) для пары показателей `fh09` и `corr0509`. Поменяйте тип точек (маркер) и цвет точек. Добавьте заголовок к графику.

# %%
for name, table in df.groupby('fh_status'):
    table.to_csv(f'{name}.csv')

# %%
plot = df.plot.scatter('fh09', 'corr0509', s=100, color = 'turquoise' )
plot.set_title('Диаграмма рассеивания для индексов Control of Corruption и Freedom House')
